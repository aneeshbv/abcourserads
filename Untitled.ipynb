# %% [markdown]
# Cell 6 (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule,
#
#         bulleted list,
#
#         numbered list,
#
#         tables,
#
#         hyperlinks,
#
#         images,
#
#         code/syntax highlighting,
#
#         blocked quotes,
#
#         strikethrough.
#
# Steps to Complete the as

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aneesh B**
#
# Analyst

# %% [markdown]
# *I am interested in data science because I like to better understand meaning. All companies have significant amount of data, and there is a lot of insight to be derived from there*

# %% [markdown]
# ### The below program stores the value of 1+5 in the variable 'a', and then prints the variable to present the output '6'

# %%
a = 1+5
print(a)
# Out:
# 6

# %% [markdown]
# #### Types of languages used for data science
#
# - R
# - Python
# - SQL
# - Javascript (Occasionally)
#
# Further information on the languages used for data science [can be found here](https://www.upgrad.com/blog/data-science-programming-languages/)
#
# sometimes data can be stored in CSV format. An example of this is a dataset on blues music artists. in this dataset, **1** means yes, and **0** means no.
#
# Name  | State | Birth Year | Born post 1906?
# ------------- | ------------- | ------------- | -------------
# Henry Thomas | Texas | 1874 | 1
# Frank Stokes   | Tenessee | 1877 | 0
#
#
# Here is further information on Blues
#
# ![image-2.png](attachment:image-2.png)
